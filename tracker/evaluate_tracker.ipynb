# %% [markdown]
# # Замер скорости и качества трекинговой системы

# %% [markdown]
# В этом ноутбуке замеряются мои лучшие по качеству детектор и трекер: детектор march-best (дообученная yolo11l) с трекером BoT-SORT с использованием RAFT (подробнее см. [`tracker.md`](tracker.md)).

# %%
experiment_name = "march-best_botsort-raft-s-128p-1upd-noups-med"

# %%
import pathlib
import time

import cv2
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import torch
import torchvision
import torchvision.transforms.functional as F
import trackeval
import tqdm.notebook as tqdm
import ultralytics.trackers.utils

sns.set_theme(style="whitegrid")
DEVICE = "cuda"
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
class RaftGMC:
    def __init__(self, model_size: str = "small", image_size: int = 128, num_flow_updates: int = 1) -> None:
        if model_size == "small":
            weights = torchvision.models.optical_flow.Raft_Small_Weights.DEFAULT
            self.model = torchvision.models.optical_flow.raft_small(weights=weights)
        elif model_size == "large":
            weights = torchvision.models.optical_flow.Raft_Large_Weights.DEFAULT
            self.model = torchvision.models.optical_flow.raft_large(weights=weights)
        else:
            raise ValueError

        self.model = self.model.to(DEVICE).eval()
        self.transforms = weights.transforms()
        self.image_size = image_size
        self.num_flow_updates = num_flow_updates
        self.last_frame = None

    def apply(self, raw_frame: np.ndarray, detections: list = None) -> np.ndarray:
        """
        `raw_frame`: frame with shape [H, W, C].
        `detections`: unused for RAFT.
        Returns a 2x3 homography matrix.
        """
        raw_frame = torch.tensor(raw_frame).permute(2, 0, 1)[None, :]    # [1, C, H, W]
        raw_frame = raw_frame[:, :, :, 10:-10]

        scale_factor = raw_frame.shape[2] / self.image_size
        raw_frame = F.resize(raw_frame, size=self.image_size, antialias=False)    # [1, C, h, w]
        if self.last_frame is None:
            self.last_frame = raw_frame
            return np.eye(2, 3)

        frame1, frame2 = self.transforms(self.last_frame, raw_frame)
        flows = self.model(    # list[num_flow_updates] of [1, 2, h, w] (or h/8, w/8 with no upsampling)
            frame1.to(DEVICE), frame2.to(DEVICE), num_flow_updates=self.num_flow_updates
        )
        medians = flows[-1].reshape(2, -1).median(dim=1).values.cpu().numpy()    # [2]
        hom = np.eye(2, 3)
        hom[:, 2] = medians * scale_factor

        self.last_frame = raw_frame
        return hom

    def reset_params(self) -> None:
        self.last_frame = None


def get_gmc(method: str):
    if method == "raft":
        return RaftGMC()
    else:
        return ultralytics.trackers.utils.gmc.GMC(method=method)


def scale_flow(flow, **kwargs):
    return flow * 8


ultralytics.trackers.bot_sort.GMC = get_gmc
torchvision.models.optical_flow.raft.upsample_flow = scale_flow

# %%
botsort_cfg = """
# Ultralytics YOLO 🚀, AGPL-3.0 license
# YOLO tracker settings for BoT-SORT tracker https://github.com/NirAharon/BoT-SORT

# Thresholds are set to their values BEFORE the Oct 2024 commit decreasing them:
# https://github.com/ultralytics/ultralytics/commit/aabd0136ec40223cf423847635a2a4de95bba63d
# They seem to work better for this task.

tracker_type: botsort # tracker type, ['botsort', 'bytetrack']
track_high_thresh: 0.5 # threshold for the first association
track_low_thresh: 0.1 # threshold for the second association
new_track_thresh: 0.6 # threshold for init new track if the detection does not match any tracks
track_buffer: 30 # buffer to calculate the time when to remove tracks
match_thresh: 0.8 # threshold for matching tracks
fuse_score: True # Whether to fuse confidence scores with the iou distances before matching
# min_box_area: 10  # threshold for min box areas(for tracker evaluation, not used for now)

# BoT-SORT settings
gmc_method: raft # method of global motion compensation
# ReID model related thresh
proximity_thresh: 0.5 # minimum IoU for valid match with ReID
appearance_thresh: 0.25 # minimum appearance similarity for ReID
with_reid: False
model: auto # uses native features if detector is YOLO else yolo11n-cls.pt
"""
with open("custom-botsort.yaml", "w") as fout:
    fout.write(botsort_cfg)

# %%
TIME_KEYS = ["preprocess", "postprocess", "inference"]

data_path = "../input/sportsmot-small/images/val"

model_path = "../input/player-tracking-models/detector/spm-yolo-l-lr0-0.0005.pt"

botsort_cfg_path = "custom-botsort.yaml"

images_dirs = sorted(pathlib.Path(data_path).iterdir())
n_frames_total = sum(len(list((images_dir / "img1").iterdir())) for images_dir in images_dirs)
pbar = tqdm.tqdm(total=n_frames_total)

outputs = {}
times_ms = {key: [] for key in TIME_KEYS + ["wall"]}

for images_dir in images_dirs:
    model = ultralytics.YOLO(model_path)
    outputs[images_dir.stem] = []

    for frame_id, image_path in enumerate(sorted((images_dir / "img1").iterdir())):
        image = cv2.imread(image_path)
        start = time.perf_counter()
        result = model.track(image, tracker=botsort_cfg_path, verbose=False, persist=True)
        end = time.perf_counter()
        if frame_id > 0:    # 1st frame can be much slower due to setup
            times_ms["wall"].append((end - start) * 1000)
            for key in TIME_KEYS:
                times_ms[key].append(result[0].speed[key])

        boxes = result[0].boxes
        if boxes.id is not None and boxes.xyxy is not None and boxes.conf is not None:
            for player_id, (x1, y1, x2, y2), conf in zip(boxes.id, boxes.xyxy, boxes.conf):
                outputs[images_dir.stem].append((
                    frame_id + 1,  # 1-indexed frame number
                    round(player_id.item()),  # player id (1-indexed already)
                    x1.item(),  # left
                    y1.item(),  # top
                    (x2 - x1).item(),  # width
                    (y2 - y1).item(),  # height
                    conf.item(),  # confidence
                    -1, -1, -1  # unused
                ))
        pbar.update()

pbar.close()
# Out:
#   0%|          | 0/26970 [00:00<?, ?it/s]
# Downloading: "https://download.pytorch.org/models/raft_small_C_T_V2-01064c6d.pth" to /root/.cache/torch/hub/checkpoints/raft_small_C_T_V2-01064c6d.pth
#
# 100%|██████████| 3.82M/3.82M [00:00<00:00, 90.4MB/s]

# %%
for key, times in times_ms.items():
    mean = np.mean(times)
    std = np.std(times)
    print(f"{key}: {mean:.1f} ± {std:.1f} ms / frame")
# Out:
# preprocess: 1.4 ± 0.1 ms / frame
# postprocess: 1.3 ± 0.1 ms / frame
# inference: 16.5 ± 0.8 ms / frame
# wall: 32.3 ± 2.8 ms / frame

# %%
out_dir = pathlib.Path("predictions/sportsmot-val") / experiment_name / "data"
out_dir.mkdir(parents=True, exist_ok=True)

for clip_name, lines in outputs.items():
    text = "".join(", ".join(map(str, line)) + "\n" for line in lines)
    (out_dir / clip_name).with_suffix(".txt").write_text(text)

# %%
# trackeval hack, these are old aliases that are now deprecated
np.float = float
np.int = int
np.bool = bool

dataset_config = {
    "GT_FOLDER": "../input/sportsmot-trackeval-ground-truths",
    "TRACKERS_FOLDER": "predictions",
    "OUTPUT_FOLDER": "trackeval-results",
    "BENCHMARK": "sportsmot",
    "SPLIT_TO_EVAL": "val"
}

evaluator = trackeval.Evaluator()
datasets = [trackeval.datasets.MotChallenge2DBox(dataset_config)]
metrics = [
    trackeval.metrics.HOTA(),
    trackeval.metrics.CLEAR(),
    trackeval.metrics.Identity(),
    trackeval.metrics.VACE()
]

evaluator.evaluate(datasets, metrics);
# Out:
# Eval Config:
# USE_PARALLEL         : False
# NUM_PARALLEL_CORES   : 8
# BREAK_ON_ERROR       : True
# RETURN_ON_ERROR      : False
# LOG_ON_ERROR         : /usr/local/lib/python3.11/dist-packages/error_log.txt
# PRINT_RESULTS        : True
# PRINT_ONLY_COMBINED  : False
# PRINT_CONFIG         : True
# TIME_PROGRESS        : True
# DISPLAY_LESS_PROGRESS : True
# OUTPUT_SUMMARY       : True
# OUTPUT_EMPTY_CLASSES : True
# OUTPUT_DETAILED      : True
# PLOT_CURVES          : True
#
# MotChallenge2DBox Config:
# GT_FOLDER            : ../input/sportsmot-trackeval-ground-truths
# TRACKERS_FOLDER      : predictions
# OUTPUT_FOLDER        : trackeval-results
# BENCHMARK            : sportsmot
# SPLIT_TO_EVAL        : val
# TRACKERS_TO_EVAL     : None
# CLASSES_TO_EVAL      : ['pedestrian']
# INPUT_AS_ZIP         : False
# PRINT_CONFIG         : True
# DO_PREPROC           : True
# TRACKER_SUB_FOLDER   : data
# OUTPUT_SUB_FOLDER    :
# TRACKER_DISPLAY_NAMES : None
# SEQMAP_FOLDER        : None
# SEQMAP_FILE          : None
# SEQ_INFO             : None
# GT_LOC_FORMAT        : {gt_folder}/{seq}/gt/gt.txt
# SKIP_SPLIT_FOL       : False
#
# CLEAR Config:
# THRESHOLD            : 0.5
# PRINT_CONFIG         : True
#
# Identity Config:
# THRESHOLD            : 0.5
# PRINT_CONFIG         : True
#
# Evaluating 1 tracker(s) on 45 sequence(s) for 1 class(es) on MotChallenge2DBox dataset using the following metrics: HOTA, CLEAR, Identity, VACE, Count
#
#
# Evaluating march-best_botsort-raft-s-128p-1upd-noups-med
#
# 1 eval_sequence(v_00HRwkvvjtQ_c001, march-best_botsort-raft-s-128p-1upd-noups-med) 1.0275 sec
# 2 eval_sequence(v_00HRwkvvjtQ_c003, march-best_botsort-raft-s-128p-1upd-noups-med) 1.0412 sec
# 3 eval_sequence(v_00HRwkvvjtQ_c005, march-best_botsort-raft-s-128p-1upd-noups-med) 0.5096 sec
# 4 eval_sequence(v_00HRwkvvjtQ_c007, march-best_botsort-raft-s-128p-1upd-noups-med) 0.6094 sec
# 5 eval_sequence(v_00HRwkvvjtQ_c008, march-best_botsort-raft-s-128p-1upd-noups-med) 0.8337 sec
# 6 eval_sequence(v_00HRwkvvjtQ_c011, march-best_botsort-raft-s-128p-1upd-noups-med) 0.6409 sec
# 7 eval_sequence(v_0kUtTtmLaJA_c004, march-best_botsort-raft-s-128p-1upd-noups-med) 0.5119 sec
# 8 eval_sequence(v_0kUtTtmLaJA_c005, march-best_botsort-raft-s-128p-1upd-noups-med) 0.3202 sec
# 9 eval_sequence(v_0kUtTtmLaJA_c006, march-best_botsort-raft-s-128p-1upd-noups-med) 0.3098 sec
# 10 eval_sequence(v_0kUtTtmLaJA_c007, march-best_botsort-raft-s-128p-1upd-noups-med) 0.2512 sec
# 11 eval_sequence(v_0kUtTtmLaJA_c008, march-best_botsort-raft-s-128p-1upd-noups-med) 0.2593 sec
# 12 eval_sequence(v_0kUtTtmLaJA_c010, march-best_botsort-raft-s-128p-1upd-noups-med) 0.2594 sec
# 13 eval_sequence(v_2QhNRucNC7E_c017, march-best_botsort-raft-s-128p-1upd-noups-med) 0.4316 sec
# 14 eval_sequence(v_4-EmEtrturE_c009, march-best_botsort-raft-s-128p-1upd-noups-med) 0.4471 sec
# 15 eval_sequence(v_4r8QL_wglzQ_c001, march-best_botsort-raft-s-128p-1upd-noups-med) 0.7530 sec
# 16 eval_sequence(v_5ekaksddqrc_c001, march-best_botsort-raft-s-128p-1upd-noups-med) 0.4845 sec
# 17 eval_sequence(v_5ekaksddqrc_c002, march-best_botsort-raft-s-128p-1upd-noups-med) 0.5437 sec
# 18 eval_sequence(v_5ekaksddqrc_c003, march-best_botsort-raft-s-128p-1upd-noups-med) 1.0543 sec
# 19 eval_sequence(v_5ekaksddqrc_c004, march-best_botsort-raft-s-128p-1upd-noups-med) 0.7108 sec
# 20 eval_sequence(v_5ekaksddqrc_c005, march-best_botsort-raft-s-128p-1upd-noups-med) 0.9018 sec
# 21 eval_sequence(v_9MHDmAMxO5I_c002, march-best_botsort-raft-s-128p-1upd-noups-med) 0.2150 sec
# 22 eval_sequence(v_9MHDmAMxO5I_c003, march-best_botsort-raft-s-128p-1upd-noups-med) 0.2053 sec
# 23 eval_sequence(v_9MHDmAMxO5I_c004, march-best_botsort-raft-s-128p-1upd-noups-med) 0.4165 sec
# 24 eval_sequence(v_9MHDmAMxO5I_c006, march-best_botsort-raft-s-128p-1upd-noups-med) 0.2420 sec
# 25 eval_sequence(v_9MHDmAMxO5I_c009, march-best_botsort-raft-s-128p-1upd-noups-med) 0.4569 sec
# 26 eval_sequence(v_BgwzTUxJaeU_c008, march-best_botsort-raft-s-128p-1upd-noups-med) 0.4242 sec
# 27 eval_sequence(v_BgwzTUxJaeU_c012, march-best_botsort-raft-s-128p-1upd-noups-med) 0.5402 sec
# 28 eval_sequence(v_BgwzTUxJaeU_c014, march-best_botsort-raft-s-128p-1upd-noups-med) 0.8754 sec
# 29 eval_sequence(v_G-vNjfx1GGc_c004, march-best_botsort-raft-s-128p-1upd-noups-med) 0.8422 sec
# 30 eval_sequence(v_G-vNjfx1GGc_c008, march-best_botsort-raft-s-128p-1upd-noups-med) 0.4280 sec
# 31 eval_sequence(v_G-vNjfx1GGc_c600, march-best_botsort-raft-s-128p-1upd-noups-med) 0.4911 sec
# 32 eval_sequence(v_G-vNjfx1GGc_c601, march-best_botsort-raft-s-128p-1upd-noups-med) 0.4706 sec
# 33 eval_sequence(v_ITo3sCnpw_k_c007, march-best_botsort-raft-s-128p-1upd-noups-med) 0.6977 sec
# 34 eval_sequence(v_ITo3sCnpw_k_c010, march-best_botsort-raft-s-128p-1upd-noups-med) 0.5399 sec
# 35 eval_sequence(v_ITo3sCnpw_k_c011, march-best_botsort-raft-s-128p-1upd-noups-med) 0.7274 sec
# 36 eval_sequence(v_ITo3sCnpw_k_c012, march-best_botsort-raft-s-128p-1upd-noups-med) 0.8022 sec
# 37 eval_sequence(v_cC2mHWqMcjk_c007, march-best_botsort-raft-s-128p-1upd-noups-med) 0.6063 sec
# 38 eval_sequence(v_cC2mHWqMcjk_c008, march-best_botsort-raft-s-128p-1upd-noups-med) 0.2435 sec
# 39 eval_sequence(v_cC2mHWqMcjk_c009, march-best_botsort-raft-s-128p-1upd-noups-med) 0.3825 sec
# 40 eval_sequence(v_dw7LOz17Omg_c053, march-best_botsort-raft-s-128p-1upd-noups-med) 0.5769 sec
# 41 eval_sequence(v_dw7LOz17Omg_c067, march-best_botsort-raft-s-128p-1upd-noups-med) 0.4535 sec
# 42 eval_sequence(v_i2_L4qquVg0_c006, march-best_botsort-raft-s-128p-1upd-noups-med) 1.0466 sec
# 43 eval_sequence(v_i2_L4qquVg0_c007, march-best_botsort-raft-s-128p-1upd-noups-med) 0.4072 sec
# 44 eval_sequence(v_i2_L4qquVg0_c009, march-best_botsort-raft-s-128p-1upd-noups-med) 0.4776 sec
# 45 eval_sequence(v_i2_L4qquVg0_c010, march-best_botsort-raft-s-128p-1upd-noups-med) 0.6878 sec
#
# All sequences for march-best_botsort-raft-s-128p-1upd-noups-med finished in 25.17 seconds
#
# HOTA: march-best_botsort-raft-s-128p-1upd-noups-med-pedestrianHOTA      DetA      AssA      DetRe     DetPr     AssRe     AssPr     LocA      OWTA      HOTA(0)   LocA(0)   HOTALocA(0)
# v_ITo3sCnpw_k_c012                 53.875    55.253    52.565    5985      4847      5401
# v_cC2mHWqMcjk_c007                 76.326    76.336    76.317    6013      1864      1866
# v_cC2mHWqMcjk_c008                 74.163    73.95     74.377    2061      726       710
# v_cC2mHWqMcjk_c009                 83.248    83.248    83.248    4060      817       817
# v_dw7LOz17Omg_c053                 73.3      73.009    73.593    6446      2383      2313
# v_dw7LOz17Omg_c067                 85.045    86.133    83.985    5994      965       1143
# v_i2_L4qquVg0_c006                 71.773    72.21     71.341    8593      3307      3452
# v_i2_L4qquVg0_c007                 87.365    91.943    83.221    4439      389       895
# v_i2_L4qquVg0_c009                 83.764    82.434    85.138    6542      1394      1142
# v_i2_L4qquVg0_c010                 51.706    52.832    50.626    4365      3897      4257
# COMBINED                           70.889    71.228    70.553    210531    85042     87869
#
# VACE: march-best_botsort-raft-s-128p-1upd-noups-med-pedestrianSFDA      ATA
# v_00HRwkvvjtQ_c001                 86.44     24.51
# v_00HRwkvvjtQ_c003                 88.375    26.211
# v_00HRwkvvjtQ_c005                 84.873    31.98
# v_00HRwkvvjtQ_c007                 83.904    29.605
# v_00HRwkvvjtQ_c008                 85.326    35.193
# v_00HRwkvvjtQ_c011                 83.59     26.668
# v_0kUtTtmLaJA_c004                 89.346    57.198
# v_0kUtTtmLaJA_c005                 87.324    71.017
# v_0kUtTtmLaJA_c006                 87.878    54.999
# v_0kUtTtmLaJA_c007                 88.22     77.704
# v_0kUtTtmLaJA_c008                 88.716    72.159
# v_0kUtTtmLaJA_c010                 88.86     70.575
# v_2QhNRucNC7E_c017                 87.806    67.072
# v_4-EmEtrturE_c009                 92.559    92.278
# v_4r8QL_wglzQ_c001                 89.501    41.54
# v_5ekaksddqrc_c001                 87.427    53.878
# v_5ekaksddqrc_c002                 89.61     48.72
# v_5ekaksddqrc_c003                 88.491    33.097
# v_5ekaksddqrc_c004                 88.646    58.19
# v_5ekaksddqrc_c005                 89.331    33.361
# v_9MHDmAMxO5I_c002                 86.107    68.573
# v_9MHDmAMxO5I_c003                 87.207    82.049
# v_9MHDmAMxO5I_c004                 79.096    43.099
# v_9MHDmAMxO5I_c006                 85.925    53.508
# v_9MHDmAMxO5I_c009                 87.112    42.057
# v_BgwzTUxJaeU_c008                 85.788    39.454
# v_BgwzTUxJaeU_c012                 85.431    44.709
# v_BgwzTUxJaeU_c014                 87.211    36.692
# v_G-vNjfx1GGc_c004                 87.402    36.761
# v_G-vNjfx1GGc_c008                 86.583    52.369
# v_G-vNjfx1GGc_c600                 84.577    35.113
# v_G-vNjfx1GGc_c601                 82.378    30.295
# v_ITo3sCnpw_k_c007                 84.058    26.741
# v_ITo3sCnpw_k_c010                 87.338    60.615
# v_ITo3sCnpw_k_c011                 85.026    43.167
# v_ITo3sCnpw_k_c012                 86.053    29.326
# v_cC2mHWqMcjk_c007                 90.496    46.392
# v_cC2mHWqMcjk_c008                 89.095    55.614
# v_cC2mHWqMcjk_c009                 90.397    55.626
# v_dw7LOz17Omg_c053                 88.628    45.931
# v_dw7LOz17Omg_c067                 89.441    68.049
# v_i2_L4qquVg0_c006                 84.431    50.173
# v_i2_L4qquVg0_c007                 84.856    75.98
# v_i2_L4qquVg0_c009                 84.8      60.724
# v_i2_L4qquVg0_c010                 85.692    28.614
# COMBINED                           86.844    46.141
#
# Count: march-best_botsort-raft-s-128p-1upd-noups-med-pedestrianDets      GT_Dets   IDs       GT_IDs
# v_00HRwkvvjtQ_c001                 11412     11276     42        10
# v_00HRwkvvjtQ_c003                 11332     11183     38        10
# v_00HRwkvvjtQ_c005                 5272      5442      27        10
# v_00HRwkvvjtQ_c007                 6251      6458      32        10
# v_00HRwkvvjtQ_c008                 9593      9538      30        10
# v_00HRwkvvjtQ_c011                 6844      6981      30        10
# v_0kUtTtmLaJA_c004                 6138      6265      19        12
# v_0kUtTtmLaJA_c005                 3747      3881      17        12
# v_0kUtTtmLaJA_c006                 3639      3705      21        12
# v_0kUtTtmLaJA_c007                 2983      3006      14        12
# v_0kUtTtmLaJA_c008                 2987      3011      15        12
# v_0kUtTtmLaJA_c010                 3016      3056      17        12
# v_2QhNRucNC7E_c017                 7019      6622      33        21
# v_4-EmEtrturE_c009                 2775      2785      13        12
# v_4r8QL_wglzQ_c001                 8243      8183      25        10
# v_5ekaksddqrc_c001                 4997      5115      19        10
# v_5ekaksddqrc_c002                 5722      5737      18        10
# v_5ekaksddqrc_c003                 11806     11800     29        10
# v_5ekaksddqrc_c004                 7711      7753      17        10
# v_5ekaksddqrc_c005                 9346      9383      29        10
# v_9MHDmAMxO5I_c002                 2622      2642      17        12
# v_9MHDmAMxO5I_c003                 2436      2441      15        12
# v_9MHDmAMxO5I_c004                 5335      5103      24        12
# v_9MHDmAMxO5I_c006                 2554      2601      22        12
# v_9MHDmAMxO5I_c009                 5467      5596      28        12
# v_BgwzTUxJaeU_c008                 4416      4475      25        10
# v_BgwzTUxJaeU_c012                 5864      5801      26        10
# v_BgwzTUxJaeU_c014                 9872      9700      24        10
# v_G-vNjfx1GGc_c004                 8013      8137      55        20
# v_G-vNjfx1GGc_c008                 4807      4573      43        20
# v_G-vNjfx1GGc_c600                 5621      5462      54        19
# v_G-vNjfx1GGc_c601                 5580      5554      65        20
# v_ITo3sCnpw_k_c007                 10219     9780      64        21
# v_ITo3sCnpw_k_c010                 8015      7705      38        20
# v_ITo3sCnpw_k_c011                 10252     9736      49        22
# v_ITo3sCnpw_k_c012                 11386     10832     59        21
# v_cC2mHWqMcjk_c007                 7879      7877      27        12
# v_cC2mHWqMcjk_c008                 2771      2787      19        12
# v_cC2mHWqMcjk_c009                 4877      4877      24        12
# v_dw7LOz17Omg_c053                 8759      8829      45        21
# v_dw7LOz17Omg_c067                 7137      6959      34        22
# v_i2_L4qquVg0_c006                 12045     11900     43        22
# v_i2_L4qquVg0_c007                 5334      4828      30        21
# v_i2_L4qquVg0_c009                 7684      7936      33        20
# v_i2_L4qquVg0_c010                 8622      8262      58        21
# COMBINED                           298400    295573    1406      641
